# %% [markdown]
# # 04 - Modelagem com Regressao Linear
#
# Objetivo:
# - definir a variavel alvo
# - separar treino e teste
# - treinar um baseline com regressao linear
# - avaliar MAE, RMSE e R2

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# carregar aqui a base final para modelagem
