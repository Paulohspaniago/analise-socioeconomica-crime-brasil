# %% [markdown]
# # 05 - Exportacao para MongoDB
#
# Objetivo:
# - salvar os dados tratados
# - persistir colecoes finais
# - guardar resultados e previsoes para consumo no Metabase

# %%
from pymongo import MongoClient

# conectar no MongoDB e publicar as colecoes finais
