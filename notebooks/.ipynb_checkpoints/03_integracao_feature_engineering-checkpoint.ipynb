# %% [markdown]
# # 03 - Integracao e Feature Engineering
#
# Objetivo:
# - integrar crime, populacao, IDH e educacao
# - consolidar a base por `codigo_municipio + ano`
# - criar features como `crime_rate_100k` e `population_growth_pct`

# %%
import pandas as pd

# unir aqui as bases ja padronizadas
